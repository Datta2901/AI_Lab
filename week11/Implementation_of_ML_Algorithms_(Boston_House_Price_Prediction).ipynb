# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Boston.csv")
# test_data = pd.read_csv("Boston_test.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
test_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14006/1149843195.py in <module>
# ----> 1 test_data.head()
#
# NameError: name 'test_data' is not defined

# %%
data.shape
# Out:
# (506, 15)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
data = data.drop(columns=['Unnamed: 0'])
# test_data = test_data.drop(columns=['Unnamed: 0'])

# %%
#cheching for null values
data.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
plt.figure(figsize = (15,8))
dataplot = sns.heatmap(data.corr(), cmap="YlGnBu", annot=True,linewidths=.8)


plt.show()

# %%
plt.figure(figsize = (15,8))
dataplot = sns.heatmap(test_data.corr(), cmap="YlGnBu", annot=True,linewidths=.8)


plt.show()

# %%
plt.plot(data.dis,data.medv,'o')
#no proper conclusion can be drawn form this feature regarding the price, hence dropping.

# %%
data = data.drop(columns=['nox'])
test_data = test_data.drop(columns=['nox'])
data = data.drop(columns=['lstat'])
test_data = test_data.drop(columns=['lstat'])

# %%
data = data.drop(columns=['dis'])
test_data = test_data.drop(columns=['dis'])

# %% [markdown]
# all the features have good correlation with the target and and relatively less correletion among them, so no need to drop any features.

# %%
#cheching the distribution of the target variable
sns.displot(data['medv'],bins = 30)
plt.show()

# %% [markdown]
# Plotting highly correlated columns to understand them better.

# %%
plt.plot(data.crim,data.medv,'o')
#x-axis = crime rate, y-axis = medv
#the lesser the crime rate, the higher are the prices.

# %%
plt.plot(data.rm,data.medv,'o')

# %%
sns.countplot(x='chas',data=data)
# Out:
# <AxesSubplot:xlabel='chas', ylabel='count'>

# %%
plt.bar(data.rad,data.medv)
# Out:
# <BarContainer object of 351 artists>

# %%
plt.plot(data.tax,data.medv,'o')

# %% [markdown]
# Training data

# %%
X_train = data.iloc[:,:-1].values
y_train = data[['medv']].values
X_test = test_data.iloc[:,:-1].values
y_test = test_data[['medv']].values

# %%
#from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.8553584482805585

# %%
y_pred = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

# %%
plt.plot(y_train,y_pred,"o")
#plotting original(x-axis) vs predicted prices(y-axis)

# %%
from sklearn.metrics import r2_score,mean_squared_error

#on training data
print('r2',r2_score(y_train,y_pred))
print('mse',mean_squared_error(y_train,y_pred))
# Out:
# r2 0.8553584482805585
# mse 10.327415480583012

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
# Out:
# <ipython-input-34-ffdb89ed8c1b>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(X_train,y_train)
# RandomForestRegressor()

# %%
y_pred = rfr.predict(X_train)
y_pred_test = rfr.predict(X_test)

# %%
plt.plot(y_train,y_pred,"o")

# %%
from sklearn.metrics import r2_score,mean_squared_error

#on training data
print('r2',r2_score(y_train,y_pred))
print('mse',mean_squared_error(y_train,y_pred))
# Out:
# r2 0.9840495573781648
# mse 1.1388625612535583

# %% [markdown]
# ###                                                                                                                          Done By
# ###                                                                                                                          Vikranth Bandaru
